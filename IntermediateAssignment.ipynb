# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05b7-tech/nasscom-Lab/blob/main/IntermediateAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

print("\n--- Task 1: Data Generation and Basic Structures ---")

print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

print("\n--- Task 2: Function Definitions and Usage ---")

print("\n--- Task 3: Core Library Usage ---")

reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)
    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

print("\n--- Task 4: File I/O ---")

report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# --- Task 2: Function Definitions and Usage ---
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2849/610952410.py in <cell line: 0>()
#      35     print(f"\nDirectory '{reports_dir}' already exists.")
#      36
# ---> 37 if len(raw_sensor_data) > 1:
#      38     first_timestamp_str = raw_sensor_data[0][0]
#      39     last_timestamp_str = raw_sensor_data[-1][0]
#
# NameError: name 'raw_sensor_data' is not defined

# %% [markdown]
# # --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
# print("\n--- Task 1: Data Generation and Basic Structures ---")
#
# # 1.1 Generate a list of 100 simulated sensor readings.
# #    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
# #    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
# #    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
# #    - device_type: Randomly chosen from DEVICE_TYPES.
# #    - location: Randomly chosen from LOCATIONS.
# #    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# # Store these in a list called 'raw_sensor_data'.
#
# # Your code for Task 1.1 here:

# %%
import random
from datetime import datetime, timedelta

DEVICE_TYPES = [
    "Temperature",
    "Humidity",
    "Pressure",
    "Light",
    "CO2"
]

LOCATIONS = [
    "Lab A",
    "Lab B",
    "Office",
    "Warehouse",
    "Factory"
]

READING_RANGES = {
    "Temperature": (20.0, 40.0),
    "Humidity": (30.0, 90.0),
    "Pressure": (950.0, 1050.0),
    "Light": (100.0, 1000.0),
    "CO2": (300.0, 1000.0)
}

start_time = datetime.now()

raw_sensor_data = []

for i in range(1, 101):
    device_id = f"DEV{i:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    timestamp = start_time + timedelta(minutes=i)
    timestamp_str = timestamp.strftime("%Y-%m-%d %H:%M:%S")

    reading = (
        timestamp_str,
        device_id,
        device_type,
        location,
        value
    )
    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:10]:
    print(reading)
# Out:
# ('2026-07-20 08:58:40', 'DEV001', 'Humidity', 'Factory', 86.24)
# ('2026-07-20 08:59:40', 'DEV002', 'Temperature', 'Lab B', 25.07)
# ('2026-07-20 09:00:40', 'DEV003', 'Pressure', 'Factory', 958.28)
# ('2026-07-20 09:01:40', 'DEV004', 'Pressure', 'Lab A', 1040.58)
# ('2026-07-20 09:02:40', 'DEV005', 'Temperature', 'Factory', 21.53)
# ('2026-07-20 09:03:40', 'DEV006', 'CO2', 'Lab B', 727.05)
# ('2026-07-20 09:04:40', 'DEV007', 'Temperature', 'Office', 25.31)
# ('2026-07-20 09:05:40', 'DEV008', 'Pressure', 'Factory', 1047.11)
# ('2026-07-20 09:06:40', 'DEV009', 'CO2', 'Factory', 393.59)
# ('2026-07-20 09:07:40', 'DEV010', 'CO2', 'Factory', 932.33)

# %% [markdown]
# # 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
# #     where 'device_type' is 'Temperature_Sensor'.
# #     Each item in 'temperature_readings' should be a dictionary with keys:
# #     'timestamp', 'device_id', 'location', 'temperature_celsius'.
#
# # Your code for Task 1.2 here:

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })
for reading in temperature_readings:
    print(reading)
# Out:
# {'timestamp': '2026-07-20 08:59:40', 'device_id': 'DEV002', 'location': 'Lab B', 'temperature_celsius': 25.07}
# {'timestamp': '2026-07-20 09:02:40', 'device_id': 'DEV005', 'location': 'Factory', 'temperature_celsius': 21.53}
# {'timestamp': '2026-07-20 09:04:40', 'device_id': 'DEV007', 'location': 'Office', 'temperature_celsius': 25.31}
# {'timestamp': '2026-07-20 09:09:40', 'device_id': 'DEV012', 'location': 'Factory', 'temperature_celsius': 22.62}
# {'timestamp': '2026-07-20 09:21:40', 'device_id': 'DEV024', 'location': 'Factory', 'temperature_celsius': 26.91}
# {'timestamp': '2026-07-20 09:22:40', 'device_id': 'DEV025', 'location': 'Lab B', 'temperature_celsius': 33.71}
# {'timestamp': '2026-07-20 09:23:40', 'device_id': 'DEV026', 'location': 'Factory', 'temperature_celsius': 25.93}
# {'timestamp': '2026-07-20 09:24:40', 'device_id': 'DEV027', 'location': 'Factory', 'temperature_celsius': 29.87}
# {'timestamp': '2026-07-20 09:26:40', 'device_id': 'DEV029', 'location': 'Lab B', 'temperature_celsius': 37.46}
# {'timestamp': '2026-07-20 09:28:40', 'device_id': 'DEV031', 'location': 'Warehouse', 'temperature_celsius': 39.58}
# {'timestamp': '2026-07-20 09:37:40', 'device_id': 'DEV040', 'location': 'Office', 'temperature_celsius': 38.12}
# {'timestamp': '2026-07-20 09:44:40', 'device_id': 'DEV047', 'location': 'Lab A', 'temperature_celsius': 31.36}
# {'timestamp': '2026-07-20 09:50:40', 'device_id': 'DEV053', 'location': 'Factory', 'temperature_celsius': 30.42}
# {'timestamp': '2026-07-20 09:51:40', 'device_id': 'DEV054', 'location': 'Factory', 'temperature_celsius': 39.89}
# {'timestamp': '2026-07-20 10:08:40', 'device_id': 'DEV071', 'location': 'Lab B', 'temperature_celsius': 29.01}
# {'timestamp': '2026-07-20 10:14:40', 'device_id': 'DEV077', 'location': 'Lab B', 'temperature_celsius': 21.95}
# {'timestamp': '2026-07-20 10:16:40', 'device_id': 'DEV079', 'location': 'Lab B', 'temperature_celsius': 39.34}
# {'timestamp': '2026-07-20 10:24:40', 'device_id': 'DEV087', 'location': 'Warehouse', 'temperature_celsius': 33.55}
# {'timestamp': '2026-07-20 10:34:40', 'device_id': 'DEV097', 'location': 'Warehouse', 'temperature_celsius': 27.62}
# {'timestamp': '2026-07-20 10:35:40', 'device_id': 'DEV098', 'location': 'Lab B', 'temperature_celsius': 32.46}
# {'timestamp': '2026-07-20 10:37:40', 'device_id': 'DEV100', 'location': 'Factory', 'temperature_celsius': 36.94}

# %% [markdown]
# # 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
#
# # Your code for Task 1.3 here:

# %%
unique_locations = {reading[3] for reading in raw_sensor_data}

print(unique_locations)
# Out:
# {'Factory', 'Lab B', 'Warehouse', 'Lab A', 'Office'}

# %% [markdown]
# # 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
# #     a tuple: (min_value, max_value) observed for that device type across all readings.
# #     Initialize with sensible large/small values.
#
# # Your code for Task 1.4 here:

# %%
device_stats = {}

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type not in device_stats:
        device_stats[device_type] = (value, value)
    else:
        min_value, max_value = device_stats[device_type]
 if value < min_value:
            min_value = value
        if value > max_value:
            max_value = value

        device_stats[device_type] = (min_value, max_value)


for device_type, stats in device_stats.items():
    print(device_type, ":", stats)
# Out:
# Humidity : (31.2, 86.24)
# Temperature : (21.53, 39.89)
# Pressure : (950.18, 1047.11)
# CO2 : (377.37, 976.4)
# Light : (114.03, 966.71)

# %% [markdown]
# # 1.5: Advanced Indexing and Slicing (Lists and Strings)
# print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
#
# # Let's use 'raw_sensor_data' and create a sample string for these tasks.
# sample_string = "PythonProgrammingIsFun"
#
# # 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
# #       Store the result in 'sliced_readings_1'.
# #       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
# #       Store the result in 'sliced_readings_2'.
#
# # Your code for Task 1.5.1 here:

# %%
sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]
ts
print("10th to 20th readings:")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# 10th to 20th readings:
# ('2026-07-20 09:07:40', 'DEV010', 'CO2', 'Factory', 932.33)
# ('2026-07-20 09:08:40', 'DEV011', 'Pressure', 'Factory', 1012.59)
# ('2026-07-20 09:09:40', 'DEV012', 'Temperature', 'Factory', 22.62)
# ('2026-07-20 09:10:40', 'DEV013', 'Pressure', 'Lab A', 998.36)
# ('2026-07-20 09:11:40', 'DEV014', 'Light', 'Warehouse', 620.19)
# ('2026-07-20 09:12:40', 'DEV015', 'Pressure', 'Lab A', 1041.56)
# ('2026-07-20 09:13:40', 'DEV016', 'Pressure', 'Factory', 1035.19)
# ('2026-07-20 09:14:40', 'DEV017', 'CO2', 'Office', 976.4)
# ('2026-07-20 09:15:40', 'DEV018', 'Humidity', 'Warehouse', 47.98)
# ('2026-07-20 09:16:40', 'DEV019', 'Light', 'Warehouse', 210.84)
# ('2026-07-20 09:17:40', 'DEV020', 'Humidity', 'Lab A', 60.33)
#
# Every 5th reading:
# ('2026-07-20 08:58:40', 'DEV001', 'Humidity', 'Factory', 86.24)
# ('2026-07-20 09:03:40', 'DEV006', 'CO2', 'Lab B', 727.05)
# ('2026-07-20 09:08:40', 'DEV011', 'Pressure', 'Factory', 1012.59)
# ('2026-07-20 09:13:40', 'DEV016', 'Pressure', 'Factory', 1035.19)
# ('2026-07-20 09:18:40', 'DEV021', 'Light', 'Office', 396.83)
# ('2026-07-20 09:23:40', 'DEV026', 'Temperature', 'Factory', 25.93)
# ('2026-07-20 09:28:40', 'DEV031', 'Temperature', 'Warehouse', 39.58)
# ('2026-07-20 09:33:40', 'DEV036', 'Light', 'Factory', 523.63)
# ('2026-07-20 09:38:40', 'DEV041', 'CO2', 'Office', 401.32)
# ('2026-07-20 09:43:40', 'DEV046', 'Light', 'Factory', 377.89)
# ('2026-07-20 09:48:40', 'DEV051', 'Light', 'Lab A', 362.2)
# ('2026-07-20 09:53:40', 'DEV056', 'Humidity', 'Office', 31.83)
# ('2026-07-20 09:58:40', 'DEV061', 'Pressure', 'Factory', 1030.84)
# ('2026-07-20 10:03:40', 'DEV066', 'Humidity', 'Lab A', 69.89)
# ('2026-07-20 10:08:40', 'DEV071', 'Temperature', 'Lab B', 29.01)
# ('2026-07-20 10:13:40', 'DEV076', 'Light', 'Factory', 150.13)
# ('2026-07-20 10:18:40', 'DEV081', 'Humidity', 'Lab B', 31.2)
# ('2026-07-20 10:23:40', 'DEV086', 'Light', 'Warehouse', 321.3)
# ('2026-07-20 10:28:40', 'DEV091', 'Pressure', 'Office', 991.5)
# ('2026-07-20 10:33:40', 'DEV096', 'Light', 'Office', 407.32)

# %% [markdown]
# # 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
# #       Store the result in 'substring_1'.
# #       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
# #       Store the result in 'substring_2'.
#
# # Your code for Task 1.5.2 here:

# %%
sample_string = "PythonProgrammingIsFun"
substring_1 = sample_string[6:17]

substring_2 = sample_string[5::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %% [markdown]
# # 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
# #       Store it in 'fifth_reading_device_type'.
# #       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
# #       Store it in 'device_type_suffix'.
#
# # Your code for Task 1.5.3 here:

# %%
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Temperature
# Device Type Suffix: rature

# %% [markdown]
# # --- Task 2: Writing and Using Functions in Python ---
# print("\n--- Task 2: Function Definitions and Usage ---")
#
# # 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
# #     that takes the 'raw_sensor_data' list and a 'target_location' string.
# #     It should return a list of all readings (as tuples) for that specific location.
#
# # Your code for Task 2.1 here:

# %%
def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

# %%
lab_a_readings = get_readings_by_location(raw_sensor_data, "Lab A")

for reading in lab_a_readings:
    print(reading)
# Out:
# ('2026-07-20 09:01:40', 'DEV004', 'Pressure', 'Lab A', 1040.58)
# ('2026-07-20 09:10:40', 'DEV013', 'Pressure', 'Lab A', 998.36)
# ('2026-07-20 09:12:40', 'DEV015', 'Pressure', 'Lab A', 1041.56)
# ('2026-07-20 09:17:40', 'DEV020', 'Humidity', 'Lab A', 60.33)
# ('2026-07-20 09:25:40', 'DEV028', 'Pressure', 'Lab A', 952.56)
# ('2026-07-20 09:29:40', 'DEV032', 'Pressure', 'Lab A', 1004.08)
# ('2026-07-20 09:31:40', 'DEV034', 'CO2', 'Lab A', 377.37)
# ('2026-07-20 09:44:40', 'DEV047', 'Temperature', 'Lab A', 31.36)
# ('2026-07-20 09:48:40', 'DEV051', 'Light', 'Lab A', 362.2)
# ('2026-07-20 10:03:40', 'DEV066', 'Humidity', 'Lab A', 69.89)
# ('2026-07-20 10:05:40', 'DEV068', 'Light', 'Lab A', 139.72)
# ('2026-07-20 10:06:40', 'DEV069', 'Pressure', 'Lab A', 1037.93)
# ('2026-07-20 10:07:40', 'DEV070', 'Pressure', 'Lab A', 1046.94)
# ('2026-07-20 10:20:40', 'DEV083', 'Humidity', 'Lab A', 51.64)
# ('2026-07-20 10:25:40', 'DEV088', 'Humidity', 'Lab A', 80.21)
# ('2026-07-20 10:32:40', 'DEV095', 'Pressure', 'Lab A', 950.18)
# ('2026-07-20 10:36:40', 'DEV099', 'CO2', 'Lab A', 442.89)

# %% [markdown]
# # 2.2 Write a function `calculate_average_temperature(temp_data_list)`
# #     that takes the 'temperature_readings' list (list of dictionaries).
# #     It should calculate and return the average temperature. Return 0.0 if the list is empty.
#
# # Your code for Task 2.2 here:

# %%
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return average

# %%
avg_temp = calculate_average_temperature(temperature_readings)
print("Average Temperature:", avg_temp)
# Out:
# Average Temperature: 28.833333333333332

# %% [markdown]
# # 2.3 Write a function `generate_report_line(reading_dict)`
# #     that takes a single temperature reading dictionary.
# #     It should return a formatted string like:
# #     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
#
# # Your code for Task 2.3 here:

# %%
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

# %%
reading = {
    "timestamp": "2026-07-20 10:30:00",
    "device_id": "DEV001",
    "location": "Lab A",
    "temperature_celsius": 28.75
}

report = generate_report_line(reading)
print(report)
# Out:
# [2026-07-20 10:30:00] Device DEV001 at Lab A: 28.75°C

# %% [markdown]
# # --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
# print("\n--- Task 3: Core Library Usage ---")
#
# # 3.1 Use the `os` module to create a new directory named 'sensor_reports'
# #     in the current working directory, if it doesn't already exist.
#
# # Your code for Task 3.1 here:
# reports_dir = 'sensor_reports'
# if not os.path.exists(reports_dir):
#     os.makedirs(reports_dir)
#     print(f"\nDirectory '{reports_dir}' created.")
# else:
#     print(f"\nDirectory '{reports_dir}' already exists.")

# %%
import os

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %% [markdown]
# # 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
# #     Convert string timestamps to datetime objects first.
# #     Print the duration in days, hours, and minutes.
#
# # Your code for Task 3.2 here:
# if len(raw_sensor_data) > 1:
#     first_timestamp_str = raw_sensor_data[0][0]
#     last_timestamp_str = raw_sensor_data[-1][0]
#
#     # Convert string to datetime object
#     # The format string must exactly match the timestamp string
#     date_format = '%Y-%m-%d %H:%M:%S'
#     first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
#     last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)
#
#     duration = last_dt - first_dt
#
#     days = duration.days
#     seconds = duration.total_seconds()
#     hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
#     minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours
#
#     print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
# else:
#     print("\nNot enough data to calculate duration.")

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print(f"Duration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("Not enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 1 hours, 39 minutes.

# %% [markdown]
# # 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
# #     using the `random` module. Store it in 'random_values'.
#
# # Your code for Task 3.3 here:

# %%
import random

random_values = [random.randint(100, 200) for _ in range(5)]

print(random_values)
# Out:
# [144, 163, 106, 124, 169]

# %% [markdown]
# # --- Task 4: File Handling in Python ---
# print("\n--- Task 4: File I/O ---")
#
# # 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
# #     Each line in the file should be generated using the `generate_report_line` function.
#
# # Your code for Task 4.1 here:
# report_filename = os.path.join(reports_dir, 'temperature_report.txt')
# try:
#     with open(report_filename, 'w') as f:
#         for reading_dict in temperature_readings:
#             line = generate_report_line(reading_dict)
#             f.write(line + '\n')
#     print(f"\nTemperature report written to '{report_filename}'.")
# except IOError as e:
#     print(f"\nError writing file '{report_filename}': {e}")

# %%
import os

report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + "\n")

    print(f"Temperature report written to '{report_filename}'.")

except IOError as e:
    print(f"Error writing file '{report_filename}': {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %% [markdown]
# # 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
# #     named 'read_report_lines'. Print the first 3 lines.
#
# # Your code for Task 4.2 here:

# %%
read_report_lines = []

try:
    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()

    print("First 3 lines of the report:")
    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file '{report_filename}': {e}")
# Out:
# First 3 lines of the report:
# [2026-07-20 10:00:00] Device DEV001 at Lab A: 28.5°C
# [2026-07-20 10:05:00] Device DEV005 at Office: 30.2°C
# [2026-07-20 10:10:00] Device DEV009 at Lab B: 27.8°C

# %%
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
